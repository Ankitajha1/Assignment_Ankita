# %% [markdown]
# Here I am using YOLOV5 for object detection for all the classes.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-129-gb54fd0a Python-3.9.16 torch-1.13.1+cu116 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.6/107.7 GB disk)

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/B
# Out:
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/B, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-129-gb54fd0a Python-3.9.16 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/494 /content/drive/MyDrive/B/CDimage001.jpg: 384x640 8 persons, 1 car, 2 motorcycles, 1 truck, 1 umbrella, 292.8ms
# image 2/494 /content/drive/MyDrive/B/CDimage002.jpg: 384x640 7 persons, 1 car, 2 motorcycles, 1 umbrella, 259.1ms
# image 3/494 /content/drive/MyDrive/B/CDimage003.jpg: 384x640 7 persons, 1 car, 2 motorcycles, 1 umbrella, 418.8ms
# ...

# %% [markdown]
# #Saving and downloading all the result images getting from yolov5

# %%
#!zip -r /DestinationPath/filename.zip /SourcePath/filename
# !zip -r /content/drive/MyDrive/Objectdetection/NA.zip /content/yolov5/runs/detect/exp2
# Out:
#   adding: content/yolov5/runs/detect/exp2/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp2/PRimage022.jpg (deflated 0%)
#   adding: content/yolov5/runs/detect/exp2/PRimage248.jpg (deflated 0%)
#   adding: content/yolov5/runs/detect/exp2/PRimage013.jpg (deflated 0%)
#   adding: content/yolov5/runs/detect/exp2/CDimage010.jpg (deflated 0%)
#   adding: content/yolov5/runs/detect/exp2/PRimage296.jpg (deflated 0%)
#   adding: content/yolov5/runs/detect/exp2/PRimage023.jpg (deflated 0%)
#   adding: content/yolov5/runs/detect/exp2/PRimage150.jpg (deflated 0%)
#   adding: content/yolov5/runs/detect/exp2/CDimage040.jpg (deflated 0%)
#   adding: content/yolov5/runs/detect/exp2/CDimage128.jpg (deflated 0%)
#   adding: content/yolov5/runs/detect/exp2/PRimage320.jpg (deflated 0%)
#   adding: content/yolov5/runs/detect/exp2/CDimage044.jpg (deflated 0%)
#   adding: content/yolov5/runs/detect/exp2/PRimage120.jpg (deflated 0%)
# ...
